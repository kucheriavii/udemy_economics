# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("./Pet Care in Ukraine.xlsx", sheet_name='Market Sizes')

# %%
df = data
a = df.iloc[0]
df.columns = a

# %%
df = df.reset_index(drop=True)
df.drop(index=0)
# Out:
# 0                                  Region  Country  Industry Edition  \
# 1                                     NaN      NaN       NaN     NaN
# 2                          Eastern Europe  Ukraine  Pet Care    2025
# 3                          Eastern Europe  Ukraine  Pet Care    2025
# 4                          Eastern Europe  Ukraine  Pet Care    2025
# 5                          Eastern Europe  Ukraine  Pet Care    2025
# ..                                    ...      ...       ...     ...
# 832                        Eastern Europe  Ukraine  Pet Care    2025
# 833                        Eastern Europe  Ukraine  Pet Care    2025
# 834                        Eastern Europe  Ukraine  Pet Care    2025
# 835                                   NaN      NaN       NaN     NaN
# 836  © Euromonitor International Ltd 2024      NaN       NaN     NaN
#
# 0        Category           Subcategory Lowest Level Hierarchy Level  \
# ...

# %%
test = df['Subcategory']

# %%
test
# Out:
# 0               Subcategory
# 1                       NaN
# 2                  Pet Care
# 3                  Pet Care
# 4                  Pet Care
#                ...
# 832      Other Pet Products
# 833      Other Pet Products
# 834      Other Pet Products
# 835                     NaN
# 836                     NaN
# Name: Subcategory, Length: 837, dtype: object
